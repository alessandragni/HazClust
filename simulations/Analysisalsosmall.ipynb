# %%
import pandas as pd
import rdata
from pathlib import Path

# Folder containing your .RData files
folder_notpen = Path("output/notpenalized")
folder_pen = Path("outputalsosmallgamma")

# List all .Rdata files
rdata_files_notpen = sorted(folder_notpen.glob("*.Rdata"))
all_data_notpen_censoradministrative = []
all_data_notpen_censornormal = []
all_data_notpen_censoruniform = []

rdata_files_pen = sorted(folder_pen.glob("*.Rdata"))
all_data_pen_censoradministrative = []
all_data_pen_censornormal = []
all_data_pen_censoruniform = []


for file in rdata_files_notpen:
    if "censoradministrative" in str(file):
        parsed = rdata.parser.parse_file(file)
        converted = rdata.conversion.convert(parsed)
        all_data_notpen_censoradministrative.append(converted)
    elif "censornormal" in str(file):
        parsed = rdata.parser.parse_file(file)
        converted = rdata.conversion.convert(parsed)
        all_data_notpen_censornormal.append(converted)
    elif "censoruniform" in str(file):
        parsed = rdata.parser.parse_file(file)
        converted = rdata.conversion.convert(parsed)
        all_data_notpen_censoruniform.append(converted)



for file in rdata_files_pen:
    if "censoradministrative" in str(file):
        parsed = rdata.parser.parse_file(file)
        converted = rdata.conversion.convert(parsed)
        all_data_pen_censoradministrative.append(converted)
    elif "censornormal" in str(file):
        parsed = rdata.parser.parse_file(file)
        converted = rdata.conversion.convert(parsed)
        all_data_pen_censornormal.append(converted)
    elif "censoruniform" in str(file):
        parsed = rdata.parser.parse_file(file)
        converted = rdata.conversion.convert(parsed)
        all_data_pen_censoruniform.append(converted)
# Out:
# /Users/alessandragni/Library/Python/3.9/lib/python/site-packages/rdata/parser/_parser.py:1217: UserWarning: Unknown file type: assumed RDS
#   warnings.warn("Unknown file type: assumed RDS")  # noqa: B028
# /Users/alessandragni/Library/Python/3.9/lib/python/site-packages/rdata/parser/_parser.py:1220: UserWarning: Wrong extension .Rdata for file in RDS format
#   warnings.warn(f"Wrong extension {extension} for file in RDS format")  # noqa: B028

# %%
import pandas as pd
import numpy as np

records = []

for d in all_data_pen_censoradministrative:
    record = {
        "seed": float(d["seed"][0]),
        "c": float(d["c"][0]),
        "k": float(d["k"][0]),
        "gammapar": float(d["gammapar"][0]),
        "n_components": float(d["n_components"][0]),
        "loglik": float(d["loglik"][0]),
        "iterations": float(d["iterations"][0]),
        "lambdaoptim": float(d["lambdaoptim"][0]),
        "censor": 'administrative'
    }

    # expand the estimates into individual columns
    for i, val in enumerate(d["estimate"]):
        record[f"estimate_{i}"] = float(val)

    records.append(record)

for d in all_data_pen_censornormal:
    record = {
        "seed": float(d["seed"][0]),
        "c": float(d["c"][0]),
        "k": float(d["k"][0]),
        "gammapar": float(d["gammapar"][0]),
        "n_components": float(d["n_components"][0]),
        "loglik": float(d["loglik"][0]),
        "iterations": float(d["iterations"][0]),
        "lambdaoptim": float(d["lambdaoptim"][0]),
        "censor": 'normal'
    }

    # expand the estimates into individual columns
    for i, val in enumerate(d["estimate"]):
        record[f"estimate_{i}"] = float(val)

    records.append(record)

for d in all_data_pen_censoruniform:
    record = {
        "seed": float(d["seed"][0]),
        "c": float(d["c"][0]),
        "k": float(d["k"][0]),
        "gammapar": float(d["gammapar"][0]),
        "n_components": float(d["n_components"][0]),
        "loglik": float(d["loglik"][0]),
        "iterations": float(d["iterations"][0]),
        "lambdaoptim": float(d["lambdaoptim"][0]),
        "censor": 'uniform'
    }

    # expand the estimates into individual columns
    for i, val in enumerate(d["estimate"]):
        record[f"estimate_{i}"] = float(val)

    records.append(record)

# build dataframe
df_pen = pd.DataFrame(records)
df_pen
# Out:
#       seed    c     k      gammapar  n_components       loglik  iterations  \
# 0      0.0  3.0  20.0  1.000000e-03           3.0  -795.372050         3.0
# 1      0.0  3.0  20.0  1.000000e-01           3.0  -878.503257        34.0
# 2      0.0  3.0  20.0  1.000000e-05           3.0  -793.804867         3.0
# 3      0.0  3.0  20.0  1.000000e-07           3.0  -793.788952         3.0
# 4      0.0  3.0  20.0  1.000000e-09           3.0  -793.788793         3.0
# ...    ...  ...   ...           ...           ...          ...         ...
# 1195   9.0  3.0  20.0  1.000000e-01           3.0 -1027.804497        31.0
# 1196   9.0  3.0  20.0  1.000000e-05           3.0  -926.194681         3.0
# 1197   9.0  3.0  20.0  1.000000e-07           3.0  -926.160093         3.0
# 1198   9.0  3.0  20.0  1.000000e-09           3.0  -926.159748         3.0
# 1199   9.0  3.0  20.0  1.000000e-11           3.0  -926.159745         3.0
#
#       lambdaoptim          censor  estimate_0  estimate_1  estimate_2  \
# 0     1000.000000  administrative    1.050744    2.509115    0.000010
# 1      117.925534  administrative    0.750998    1.737520    0.000398
# 2     1000.000000  administrative    1.058303    2.528844    0.000009
# 3     1000.000000  administrative    1.059279    2.529220    0.000009
# 4     1000.000000  administrative    1.059279    2.529220    0.000009
# ...           ...             ...         ...         ...         ...
# 1195    97.372071          normal    0.598688    1.739716    0.000481
# 1196  1440.000000          normal    0.620665    2.588357    0.000006
# 1197  1440.000000          normal    0.621027    2.588661    0.000006
# 1198  1440.000000          normal    0.621027    2.588661    0.000006
# 1199  1440.000000          normal    0.621027    2.588661    0.000006
#
#       estimate_3
# 0       0.698357
# 1       0.438235
# 2       0.704716
# 3       0.704828
# 4       0.704828
# ...          ...
# 1195    0.451339
# 1196    0.725151
# 1197    0.725276
# 1198    0.725276
# 1199    0.725276
#
# [1200 rows x 13 columns]

# %% [markdown]
# ### now we transform back the estimate_2 which is $\xi^\rho$ to make \xi

# %%
df_pen['estimate_2'] = df_pen['estimate_2']**(1/df_pen['estimate_1'])

# %%
df_pen
# Out:
#       seed    c     k      gammapar  n_components       loglik  iterations  \
# 0      0.0  3.0  20.0  1.000000e-03           3.0  -795.372050         3.0
# 1      0.0  3.0  20.0  1.000000e-01           3.0  -878.503257        34.0
# 2      0.0  3.0  20.0  1.000000e-05           3.0  -793.804867         3.0
# 3      0.0  3.0  20.0  1.000000e-07           3.0  -793.788952         3.0
# 4      0.0  3.0  20.0  1.000000e-09           3.0  -793.788793         3.0
# ...    ...  ...   ...           ...           ...          ...         ...
# 1195   9.0  3.0  20.0  1.000000e-01           3.0 -1027.804497        31.0
# 1196   9.0  3.0  20.0  1.000000e-05           3.0  -926.194681         3.0
# 1197   9.0  3.0  20.0  1.000000e-07           3.0  -926.160093         3.0
# 1198   9.0  3.0  20.0  1.000000e-09           3.0  -926.159748         3.0
# 1199   9.0  3.0  20.0  1.000000e-11           3.0  -926.159745         3.0
#
#       lambdaoptim          censor  estimate_0  estimate_1  estimate_2  \
# 0     1000.000000  administrative    1.050744    2.509115    0.009995
# 1      117.925534  administrative    0.750998    1.737520    0.011037
# 2     1000.000000  administrative    1.058303    2.528844    0.009970
# 3     1000.000000  administrative    1.059279    2.529220    0.009977
# 4     1000.000000  administrative    1.059279    2.529220    0.009977
# ...           ...             ...         ...         ...         ...
# 1195    97.372071          normal    0.598688    1.739716    0.012385
# 1196  1440.000000          normal    0.620665    2.588357    0.009793
# 1197  1440.000000          normal    0.621027    2.588661    0.009789
# 1198  1440.000000          normal    0.621027    2.588661    0.009789
# 1199  1440.000000          normal    0.621027    2.588661    0.009789
#
#       estimate_3
# 0       0.698357
# 1       0.438235
# 2       0.704716
# 3       0.704828
# 4       0.704828
# ...          ...
# 1195    0.451339
# 1196    0.725151
# 1197    0.725276
# 1198    0.725276
# 1199    0.725276
#
# [1200 rows x 13 columns]

# %%
df_pen[df_pen.k == 20].groupby(['k'])['iterations'].value_counts()
# Out:
# k     iterations
# 20.0  3.0           662
#       38.0           47
#       40.0           46
#       35.0           43
#       36.0           43
#       39.0           35
#       41.0           35
#       33.0           30
#       37.0           28
#       32.0           20
#       42.0           19
#       31.0           17
#       34.0           16
#       6.0            15
#       29.0           14
#       43.0           12
#       26.0           11
#       30.0           11
#       4.0            10
#       7.0            10
#       28.0            9
#       2.0             8
#       25.0            8
#       200.0           7
#       27.0            6
#       5.0             5
#       56.0            4
#       21.0            3
#       49.0            3
#       10.0            2
#       22.0            2
#       44.0            2
#       53.0            2
#       8.0             1
#       9.0             1
#       14.0            1
#       18.0            1
#       19.0            1
#       23.0            1
#       24.0            1
#       45.0            1
#       46.0            1
#       47.0            1
#       51.0            1
#       55.0            1
#       63.0            1
#       65.0            1
#       67.0            1
# Name: count, dtype: int64

# %%
df_pen[df_pen.k == 50].groupby(['k'])['iterations'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
import pandas as pd
import numpy as np

records = []

for d in all_data_notpen_censoradministrative:
    record = {
        "seed": float(d["seed"][0]),
        "c": float(d["c"][0]),
        "k": float(d["k"][0]),
        "gammapar": float(d["gammapar"][0]),
        "loglik": float(d["loglik"][0]),
        "iterations": float(d["iterations"][0]),
        "lambdaoptim": float(d["lambdaoptim"][0]),
        "censor": 'administrative'
    }

    # expand the estimates into individual columns
    for i, val in enumerate(d["estimate"]):
        record[f"estimate_{i}"] = float(val)

    records.append(record)

for d in all_data_notpen_censornormal:
    record = {
        "seed": float(d["seed"][0]),
        "c": float(d["c"][0]),
        "k": float(d["k"][0]),
        "gammapar": float(d["gammapar"][0]),
        "loglik": float(d["loglik"][0]),
        "iterations": float(d["iterations"][0]),
        "lambdaoptim": float(d["lambdaoptim"][0]),
        "censor": 'normal'
    }

    # expand the estimates into individual columns
    for i, val in enumerate(d["estimate"]):
        record[f"estimate_{i}"] = float(val)

    records.append(record)

for d in all_data_notpen_censoruniform:
    record = {
        "seed": float(d["seed"][0]),
        "c": float(d["c"][0]),
        "k": float(d["k"][0]),
        "gammapar": float(d["gammapar"][0]),
        "loglik": float(d["loglik"][0]),
        "iterations": float(d["iterations"][0]),
        "lambdaoptim": float(d["lambdaoptim"][0]),
        "censor": 'uniform'
    }

    # expand the estimates into individual columns
    for i, val in enumerate(d["estimate"]):
        record[f"estimate_{i}"] = float(val)

    records.append(record)

# build dataframe
df_notpen = pd.DataFrame(records)
df_notpen
# Out:
#      seed    c     k  gammapar      loglik  iterations  lambdaoptim  \
# 0     0.0  3.0  20.0       0.0 -793.788792         0.0       1000.0
# 1     0.0  3.0  50.0       0.0 -793.788792         0.0       1000.0
# 2    10.0  3.0  20.0       0.0 -886.795026         0.0       1000.0
# 3    10.0  3.0  50.0       0.0 -886.795026         0.0       1000.0
# 4    11.0  3.0  20.0       0.0 -842.560518         0.0       1000.0
# ..    ...  ...   ...       ...         ...         ...          ...
# 595  98.0  3.0  50.0       0.0 -876.336817         0.0       1000.0
# 596  99.0  3.0  20.0       0.0 -980.684042         0.0       1000.0
# 597  99.0  3.0  50.0       0.0 -980.684042         0.0       1000.0
# 598   9.0  3.0  20.0       0.0 -886.693465         0.0       1000.0
# 599   9.0  3.0  50.0       0.0 -886.693465         0.0       1000.0
#
#              censor  estimate_0  estimate_1  estimate_2  estimate_3
# 0    administrative    1.059279    2.529220    0.000009    0.704828
# 1    administrative    1.059279    2.529220    0.000009    0.704828
# 2    administrative    0.614411    2.462905    0.000012    0.683281
# 3    administrative    0.614411    2.462905    0.000012    0.683281
# 4    administrative    0.714209    2.462628    0.000012    0.693482
# ..              ...         ...         ...         ...         ...
# 595         uniform    0.194501    2.533445    0.000010    0.701042
# 596         uniform    0.839672    2.529161    0.000009    0.698438
# 597         uniform    0.839672    2.529161    0.000009    0.698438
# 598         uniform    0.602491    2.542613    0.000007    0.717589
# 599         uniform    0.602491    2.542613    0.000007    0.717589
#
# [600 rows x 12 columns]

# %% [markdown]
# ### now we transform back the estimate_2 which is $\xi^\rho$ to make \xi

# %%
df_notpen['estimate_2'] = df_notpen['estimate_2']**(1/df_notpen['estimate_1'])

# %%
df = pd.concat([df_notpen, df_pen], axis = 0)

# %%
df
# Out:
#       seed    c     k      gammapar       loglik  iterations  lambdaoptim  \
# 0      0.0  3.0  20.0  0.000000e+00  -793.788792         0.0  1000.000000
# 1      0.0  3.0  50.0  0.000000e+00  -793.788792         0.0  1000.000000
# 2     10.0  3.0  20.0  0.000000e+00  -886.795026         0.0  1000.000000
# 3     10.0  3.0  50.0  0.000000e+00  -886.795026         0.0  1000.000000
# 4     11.0  3.0  20.0  0.000000e+00  -842.560518         0.0  1000.000000
# ...    ...  ...   ...           ...          ...         ...          ...
# 1195   9.0  3.0  20.0  1.000000e-01 -1027.804497        31.0    97.372071
# 1196   9.0  3.0  20.0  1.000000e-05  -926.194681         3.0  1440.000000
# 1197   9.0  3.0  20.0  1.000000e-07  -926.160093         3.0  1440.000000
# 1198   9.0  3.0  20.0  1.000000e-09  -926.159748         3.0  1440.000000
# 1199   9.0  3.0  20.0  1.000000e-11  -926.159745         3.0  1440.000000
#
#               censor  estimate_0  estimate_1  estimate_2  estimate_3  \
# 0     administrative    1.059279    2.529220    0.009977    0.704828
# 1     administrative    1.059279    2.529220    0.009977    0.704828
# 2     administrative    0.614411    2.462905    0.009931    0.683281
# 3     administrative    0.614411    2.462905    0.009931    0.683281
# 4     administrative    0.714209    2.462628    0.010128    0.693482
# ...              ...         ...         ...         ...         ...
# 1195          normal    0.598688    1.739716    0.012385    0.451339
# 1196          normal    0.620665    2.588357    0.009793    0.725151
# 1197          normal    0.621027    2.588661    0.009789    0.725276
# 1198          normal    0.621027    2.588661    0.009789    0.725276
# 1199          normal    0.621027    2.588661    0.009789    0.725276
#
#       n_components
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 1195           3.0
# 1196           3.0
# 1197           3.0
# 1198           3.0
# 1199           3.0
#
# [1800 rows x 13 columns]

# %%
df.n_components.value_counts()
# Out:
# n_components
# 3.0    1198
# 2.0       2
# Name: count, dtype: int64

# %%
df.loc[df.gammapar!=0, 'n_components'].value_counts()
# Out:
# n_components
# 3.0    1198
# 2.0       2
# Name: count, dtype: int64

# %%
df = df.loc[(df['n_components'] == 3) | (df['n_components'].isna())]

# %%
df = df.loc[(df['k'] == 20)] # ANALYSIS RESTRICTED TO K=20
df = df.loc[(df['gammapar'] != 0.5)]

# %%
# Filter & convert
dfx = df.loc[df.censor == 'administrative', ['loglik', 'gammapar']].apply(pd.to_numeric, errors='coerce')
    
import seaborn as sns

sns.boxplot(
    data=dfx,
    x="gammapar",
    y='loglik',
    hue="gammapar",
    palette="Greys",
    dodge=False
)
# Out:
# <Axes: xlabel='gammapar', ylabel='loglik'>

# %% [markdown]
# ## Bias of estimators

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")

# True parameter values
true_values = {
    'estimate_0': 0.5,
    'estimate_1': 2.5,
    'estimate_2': 0.01,
    'estimate_3': np.log(2)
}

# Define descriptive titles for each estimate
titles = {
    'estimate_0': r"(i) $\theta$", # r"Var$(u_g)$",
    'estimate_1': r"(ii) $\rho$",
    'estimate_2': r"(iii) $\xi$",
    'estimate_3': r"(iv) $\beta$"
}

TITLE_SIZE = 16
LABEL_SIZE = 12
TICK_SIZE  = 13

estimates = list(titles.keys())

for j in ['administrative', 'normal']:
    
    fig, axes = plt.subplots(
        1, len(estimates),
        figsize=(4.2 * len(estimates), 4.7),
        sharey=False
    )

    for ax, est in zip(axes, estimates):

        # Filter & convert
        dfx = df.loc[df.censor == j, [est, 'gammapar']].apply(pd.to_numeric, errors='coerce')
        
        sns.boxplot(
            data=dfx,
            x="gammapar",
            y=est,
            hue="gammapar",
            palette="Greys",
            dodge=False,  
            ax=ax
        )

        # True value
        ax.axhline(
            y=true_values[est],
            color='red',
            linestyle='--',
            label="True value"
        )

        # Clean subplot
        ax.set_xlabel("")
        ax.set_ylabel("")
        ax.set_xticks([])
        ax.set_xticklabels([])
        ax.set_title(f"{titles[est]}", fontsize=TITLE_SIZE)

        # REMOVE subplot legend (keep only global one)
        ax.get_legend().remove()

    handles, labels = axes[0].get_legend_handles_labels()

    fig.subplots_adjust(bottom=0.15, top=0.8)

    fig.legend(
        handles, labels,
        title=r"$\gamma$",
        loc="lower center",
        ncol=len(labels),
        fontsize=TICK_SIZE,
        title_fontsize=TICK_SIZE
    )


    # Global title
    plt.suptitle(
        rf"Estimates $\hat{{p}}$ – {j} censoring",
        fontsize=TITLE_SIZE
    )

    fig.subplots_adjust(top=0.85, bottom=0.18)
    plt.savefig(f"Plots/Estimates_{j}.pdf", bbox_inches="tight")
    plt.close()

# %%
# import pandas as pd
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
# from matplotlib.ticker import ScalarFormatter

# # Modern clean style
# sns.set_style("whitegrid")
# #sns.set_context("talk")  

# # Define the true values for each estimate
# true_values = {
#     'estimate_0': 0.5,
#     'estimate_1': 2.5,
#     'estimate_2': 0.01,
#     'estimate_3': np.log(2)
# }

# # Define descriptive titles for each estimate
# titles = {
#     'estimate_0': r"(i) $\theta$", # r"Var$(u_g)$",
#     'estimate_1': r"(ii) $\rho$",
#     'estimate_2': r"(iii) $\xi$",
#     'estimate_3': r"(iv) $\beta$"
# }

# numb = {
#     'estimate_0': "(i)",
#     'estimate_1': "(ii)",
#     'estimate_2': "(iii)",
#     'estimate_3': "(iv)"
# }


# # Consistent style parameters
# TITLE_SIZE = 22
# LABEL_SIZE = 18
# TICK_SIZE  = 16


# for j in ['administrative', 'normal', 'uniform']:
#     for i in ['estimate_0', 'estimate_1', 'estimate_2', 'estimate_3']:
#         cols = [i, 'gammapar']
#         dfx = df.loc[df.censor==j, cols].apply(pd.to_numeric, errors='coerce')

#         # Plot using seaborn boxplot
#         plt.figure(figsize=(5.5, 6))
#         sns.boxplot(data=dfx, x='gammapar', y=i, palette='Greys')
        
#         # Overlay the true value as a horizontal line
#         plt.axhline(y=true_values[i], color='red', linestyle='--', label='True Value')

#         # Bigger text everywhere
#         plt.title(f"{numb[i]} {titles[i]} - {j} cens.", fontsize=TITLE_SIZE)
#         plt.xlabel(r"$\gamma$", fontsize=LABEL_SIZE)
#         plt.ylabel(titles[i], fontsize=LABEL_SIZE)
#         plt.xticks(fontsize=TICK_SIZE)
#         plt.yticks(fontsize=TICK_SIZE)

#         #____
#         # get the tick locations (categories)
#         ax = plt.gca()
#         ticks = ax.get_xticks()

#         # original values from the dataframe
#         vals = dfx['gammapar'].unique()

#         # Sort to match seaborn order
#         vals = np.sort(vals)

#         # Create formatted labels
#         labels = []
#         for x in vals:
#             if x == 0:
#                 labels.append("0")
#             elif abs(x) < 0.01:
#                 exp = int(np.floor(np.log10(abs(x))))
#                 labels.append(rf"$10^{{{exp}}}$")
#             else:
#                 labels.append(f"{x:g}")

#         # Apply them
#         ax.set_xticklabels(labels, fontsize=TICK_SIZE)
#         #_________

#         # plt.show()
        
#         # Adjust legend so it shows only the true value
#         #plt.legend([f'True Value: {true_values[i]}'], loc='best')
        
#         plt.subplots_adjust(top=0.90, bottom=0.15)

#         # add enough space on the left so the y-label is fully visible
#         plt.gcf().subplots_adjust(left=0.2)

#         # Save the figure (PDF for LaTeX)
#         plt.savefig(f"Plots/Distribution_{j}_{i}.pdf", pad_inches=0.1)
#         plt.close()

# %% [markdown]
# ## Bias-variance trade-off

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

for j in ['administrative', 'normal']:
    dfx = df[df.censor == j].copy()

    #_____________________
    # MSE

    # Define the true values for each estimate
    truevals = np.array([0.5, 2.5, 0.001, np.log(2)])

    # Compute L2 squared differences for each beta
    for i in range(4):
        dfx[f'diff_{i}'] = (dfx[f'estimate_{i}'] - truevals[i])**2

    # Melt dataframe to long format for plotting
    df_long = dfx.melt(
        id_vars=['gammapar'], 
        value_vars=['diff_0', 'diff_1', 'diff_2', 'diff_3'],
        var_name='Beta', 
        value_name='SquaredError'
    )

    # Clean up Beta names
    df_long['Beta'] = df_long['Beta'].map({'diff_0': r"(i) $\theta$", 'diff_1': r"(ii) $\rho$", 'diff_2': r"(iii) $\xi$", 'diff_3': r"(iv) $\beta$"})

    # --- PLOTTING ---
    plt.figure(figsize=(10, 6))

    # OLD VERSION
    # sns.boxplot(data=df_long, x='Beta', y='SquaredError', hue='gammapar', palette='Greys')
    # plt.title(f"(i) MSE  - {j} censoring", fontsize=TITLE_SIZE)
    # plt.xlabel("", fontsize=LABEL_SIZE)
    # plt.ylabel(r"$\|\hat{p} - p\|_2^2$", fontsize=LABEL_SIZE)

    # plt.xticks(fontsize=TICK_SIZE)
    # plt.yticks(fontsize=TICK_SIZE)

    # plt.grid(axis='y', linestyle='--', alpha=0.5)
    # plt.legend(title=r'$\gamma$', fontsize=TICK_SIZE-3, title_fontsize=LABEL_SIZE-3)

    # # Save the figure (PDF for LaTeX)
    # plt.savefig(f"Plots/fig_MSE_{j}.pdf", bbox_inches="tight")
    # plt.close()

    # plt.show()


    betas = df_long['Beta'].unique()

    fig, axes = plt.subplots(
        1, len(betas),
        figsize=(4 * len(betas), 4.7),
        sharey=False
    )

    if len(betas) == 1:
        axes = [axes]

    for ax, beta in zip(axes, betas):
        df_sub = df_long[df_long['Beta'] == beta]

        sns.boxplot(
            data=df_sub,
            x="Beta",
            y="SquaredError",
            hue="gammapar",
            palette="Greys",
            ax=ax
        )

        ax.set_xlabel("")
        ax.set_ylabel("")
        ax.set_xticks([])
        ax.set_xticklabels([])
        ax.set_title(beta, fontsize=TITLE_SIZE)

        # Remove legend in each subplot
        ax.get_legend().remove()

        handles, labels = axes[0].get_legend_handles_labels()

        fig.subplots_adjust(bottom=0.2, top=0.82)

        fig.legend(
            handles, labels,
            title=r"$\gamma$",
            loc="lower center",
            ncol=len(labels),
            fontsize=TICK_SIZE,
            title_fontsize=TICK_SIZE
        )

    plt.suptitle(
        rf"MSE $\|\hat{{p}} - p\|_2^2$ - {j} censoring",
        fontsize=TITLE_SIZE
    )

    # plt.show()
    # Save figure
    plt.savefig(f"Plots/fig_MSE_{j}.pdf", bbox_inches="tight")
    plt.close()



    #_____________________
    # VARIANCE

    # Keep relevant columns
    df_true = dfx[['seed', 'gammapar', 'estimate_0', 'estimate_1', 'estimate_2', 'estimate_3']].copy()

    # --- Compute squared deviations by gammapar ---
    for i in range(4):
        col = f'estimate_{i}'
        # Compute mean per gammapar group
        df_true[f'{col}_mean'] = df_true.groupby('gammapar')[col].transform('mean')
        # Compute squared deviation from that mean
        df_true[f'{col}'] = (df_true[col] - df_true[f'{col}_mean'])**2

    # --- Melt to long format for plotting ---
    df_long = df_true.melt(
        id_vars=['gammapar'],
        value_vars=['estimate_0', 'estimate_1', 'estimate_2', 'estimate_3'],
        var_name='Beta',
        value_name='SquaredDeviation'
    )

    # Clean up Beta names
    df_long['Beta'] = df_long['Beta'].map(titles)

    # --- Plotting ---
    plt.figure(figsize=(6, 6))
    # OLD VERSION
    # sns.boxplot(data=df_long, x='Beta', y='SquaredDeviation', hue='gammapar', palette='Greys')

    #**********************************************
    # Get unique parameters in the order you want
    betas = df_long['Beta'].unique()

    # One subplot per Beta
    fig, axes = plt.subplots(1, len(betas), figsize=(4 * len(betas), 4.7), sharey=False)

    if len(betas) == 1:
        axes = [axes]  

    for ax, beta in zip(axes, betas):
        df_sub = df_long[df_long['Beta'] == beta]

        sns.boxplot(
            data=df_sub,
            x="Beta",
            y="SquaredDeviation",
            hue="gammapar",
            palette="Greys",
            ax=ax
        )
        ax.set_title(beta)
        ax.set_xlabel("")
        ax.set_ylabel("") #r"$\|\hat{p} - \bar{\hat{p}}\|_2^2$")

        ax.set_xticks([])         # remove tick positions
        ax.set_xticklabels([])    # remove tick labels

        # Title (keep it)
        ax.set_title(beta, fontsize=14)
        ax.get_legend().remove()

    # Move legend outside
    handles, labels = axes[0].get_legend_handles_labels()

    fig.subplots_adjust(bottom=0.2, top=0.82) 
    fig.legend(
        handles, labels, title=r"$\gamma$",
        loc="lower center",
        ncol=len(labels),
        fontsize=TICK_SIZE,
        title_fontsize=TICK_SIZE
        #bbox_to_anchor=(0.5, 0.02) #,   # push legend further down
        #frameon=False
    )

    plt.suptitle(rf"Variance $\|\hat{{p}} - \bar{{\hat{{p}}}}\|_2^2$ - {j} censoring", fontsize=TITLE_SIZE)

    # plt.show()
    # Save the figure (PDF for LaTeX)
    plt.savefig(f"Plots/fig_Variance_{j}.pdf", bbox_inches="tight")
    plt.close()

    #*********************************************

    # OLD VERSION
    # plt.title(f"(ii) Variance - {j} censoring", fontsize=TITLE_SIZE)
    # plt.xlabel("", fontsize=LABEL_SIZE)
    # plt.ylabel(r"$\|\hat{p} - \bar{\hat{p}}\|_2^2$", fontsize=LABEL_SIZE)

    # plt.yticks(fontsize=TICK_SIZE)

    # plt.grid(axis='y', linestyle='--', alpha=0.5)
    # # plt.legend(title=r'$\gamma$', fontsize=TICK_SIZE-3, title_fontsize=LABEL_SIZE-3)

    # # Save the figure (PDF for LaTeX)
    # plt.savefig(f"Plots/fig_Variance_{j}.pdf", bbox_inches="tight")
    # plt.close()

    # plt.show()

# %% [markdown]
# ## Accuracy

# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
from sklearn.metrics import normalized_mutual_info_score
from sklearn.metrics import adjusted_rand_score
import pandas as pd
import rdata
from pathlib import Path

# Folder containing your .RData files
folder_pen = Path("outputalsosmallgamma")

# List all .Rdata files
rdata_files_pen = sorted(folder_pen.glob("*.Rdata"))
all_data_pen_censoradministrative = []
all_data_pen_censornormal = []
all_data_pen_censoruniform = []


for file in rdata_files_pen:
    if "censoradministrative" in str(file):
        parsed = rdata.parser.parse_file(file)
        converted = rdata.conversion.convert(parsed)
        all_data_pen_censoradministrative.append(converted)
    elif "censornormal" in str(file):
        parsed = rdata.parser.parse_file(file)
        converted = rdata.conversion.convert(parsed)
        all_data_pen_censornormal.append(converted)
    elif "censoruniform" in str(file):
        parsed = rdata.parser.parse_file(file)
        converted = rdata.conversion.convert(parsed)
        all_data_pen_censoruniform.append(converted)

# %%
def simple_relabel(true_labels, pred_labels):
    """
    Relabel predicted clusters to match true labels based on maximum overlap.
    Works when number of clusters is small (e.g., 3) and you just want names to match.
    """
    true_labels = pd.Series(true_labels)
    pred_labels = pd.Series(pred_labels)
    
    unique_true = true_labels.unique()
    unique_pred = pred_labels.unique()
    
    mapping = {}
    used_true = set()
    
    for p in unique_pred:
        # find the true label with max overlap
        overlaps = {t: ((true_labels==t) & (pred_labels==p)).sum() for t in unique_true if t not in used_true}
        best_true = max(overlaps, key=overlaps.get)
        mapping[p] = best_true
        used_true.add(best_true)
    
    new_preds = pred_labels.map(mapping)
    return new_preds, mapping

# %%
from sklearn.metrics import normalized_mutual_info_score, adjusted_rand_score

gammapars_all = {}
accuracy_all = {}
ari_all = {}
nmi_all = {}

numb = {
    'admin': "(i) Administrative censoring",
    'norm': "(ii) Normal censoring",
    'unif': "(iii) Uniform censoring"
}


for j,name in [(all_data_pen_censoradministrative, "admin"), (all_data_pen_censornormal, "norm"), (all_data_pen_censoruniform, "unif")]:
    datasets = []
    gammapars = []
    for d in j:
        if d["n_components"] == 3 and d["k"] == 20:
            if d['gammapar'] != 0.5:
                datasets.append(pd.DataFrame(d["clusters"]))
                gammapars.append(d["gammapar"][0])

        
    accuracy_list = []
    nmi_list = []
    ari_list = []

    for df in datasets:
        # Extract the two cluster membership columns
        true_labels = df.iloc[:, 0]
        pred_labels = df.iloc[:, 1]

        # Align predicted clusters to true clusters
        aligned_preds, mapping = simple_relabel(true_labels, pred_labels)

        # Add an indicator column for exact matches
        df["same_membership"] = (true_labels == aligned_preds).astype(int)


        # Compute metrics
        nmi = normalized_mutual_info_score(true_labels, aligned_preds)
        print(f"NMI: {nmi:.3f}")
        nmi_list.append(nmi)

        ari = adjusted_rand_score(true_labels, aligned_preds)
        print(f"ARI: {ari:.3f}") 
        ari_list.append(ari)   

        accuracy = df["same_membership"].mean()
        print(f"Accuracy: {accuracy:.3f}")   
        accuracy_list.append(accuracy)

        print('\n')

    
    gammapars_all[f"{name}"] = np.array(gammapars)
    accuracy_all[f"{name}"] = np.array(accuracy_list)
    ari_all[f"{name}"] = np.array(ari_list)
    nmi_all[f"{name}"] = np.array(nmi_list)
# Out:
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.748
# ARI: 0.660
# Accuracy: 0.844
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.786
# ARI: 0.729
# Accuracy: 0.886
#
#
# NMI: 0.792
# ARI: 0.740
# Accuracy: 0.892
#
#
# NMI: 0.368
# ARI: 0.200
# Accuracy: 0.536
#
#
# NMI: 0.368
# ARI: 0.200
# Accuracy: 0.536
#
#
# NMI: 0.368
# ARI: 0.200
# Accuracy: 0.536
#
#
# NMI: 0.368
# ARI: 0.200
# Accuracy: 0.536
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.519
# ARI: 0.376
# Accuracy: 0.610
#
#
# NMI: 0.463
# ARI: 0.293
# Accuracy: 0.712
#
#
# NMI: 0.519
# ARI: 0.376
# Accuracy: 0.610
#
#
# NMI: 0.519
# ARI: 0.376
# Accuracy: 0.610
#
#
# NMI: 0.519
# ARI: 0.376
# Accuracy: 0.610
#
#
# NMI: 0.519
# ARI: 0.376
# Accuracy: 0.610
#
#
# NMI: 0.751
# ARI: 0.662
# Accuracy: 0.848
#
#
# NMI: 0.476
# ARI: 0.308
# Accuracy: 0.716
#
#
# NMI: 0.751
# ARI: 0.662
# Accuracy: 0.848
#
#
# NMI: 0.751
# ARI: 0.662
# Accuracy: 0.848
#
#
# NMI: 0.751
# ARI: 0.662
# Accuracy: 0.848
#
#
# NMI: 0.751
# ARI: 0.662
# Accuracy: 0.848
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.783
# ARI: 0.718
# Accuracy: 0.888
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.735
# ARI: 0.642
# Accuracy: 0.804
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.797
# ARI: 0.743
# Accuracy: 0.900
#
#
# NMI: 0.719
# ARI: 0.593
# Accuracy: 0.802
#
#
# NMI: 0.797
# ARI: 0.743
# Accuracy: 0.900
#
#
# NMI: 0.797
# ARI: 0.743
# Accuracy: 0.900
#
#
# NMI: 0.797
# ARI: 0.743
# Accuracy: 0.900
#
#
# NMI: 0.797
# ARI: 0.743
# Accuracy: 0.900
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.714
# ARI: 0.589
# Accuracy: 0.772
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.834
# ARI: 0.811
# Accuracy: 0.928
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.855
# ARI: 0.844
# Accuracy: 0.942
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.716
# ARI: 0.581
# Accuracy: 0.802
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.744
# ARI: 0.645
# Accuracy: 0.836
#
#
# NMI: 0.763
# ARI: 0.683
# Accuracy: 0.862
#
#
# NMI: 0.763
# ARI: 0.683
# Accuracy: 0.862
#
#
# NMI: 0.763
# ARI: 0.683
# Accuracy: 0.862
#
#
# NMI: 0.763
# ARI: 0.683
# Accuracy: 0.862
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.820
# ARI: 0.788
# Accuracy: 0.918
#
#
# NMI: 0.738
# ARI: 0.637
# Accuracy: 0.828
#
#
# NMI: 0.820
# ARI: 0.788
# Accuracy: 0.918
#
#
# NMI: 0.820
# ARI: 0.788
# Accuracy: 0.918
#
#
# NMI: 0.820
# ARI: 0.788
# Accuracy: 0.918
#
#
# NMI: 0.820
# ARI: 0.788
# Accuracy: 0.918
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.724
# ARI: 0.607
# Accuracy: 0.802
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.372
# ARI: 0.208
# Accuracy: 0.614
#
#
# NMI: 0.536
# ARI: 0.446
# Accuracy: 0.682
#
#
# NMI: 0.476
# ARI: 0.303
# Accuracy: 0.714
#
#
# NMI: 0.476
# ARI: 0.303
# Accuracy: 0.714
#
#
# NMI: 0.476
# ARI: 0.303
# Accuracy: 0.714
#
#
# NMI: 0.476
# ARI: 0.303
# Accuracy: 0.714
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.766
# ARI: 0.690
# Accuracy: 0.868
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.851
# ARI: 0.835
# Accuracy: 0.940
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.765
# ARI: 0.685
# Accuracy: 0.864
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.765
# ARI: 0.685
# Accuracy: 0.864
#
#
# NMI: 0.765
# ARI: 0.685
# Accuracy: 0.864
#
#
# NMI: 0.765
# ARI: 0.685
# Accuracy: 0.864
#
#
# NMI: 0.765
# ARI: 0.685
# Accuracy: 0.864
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.707
# ARI: 0.565
# Accuracy: 0.782
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.745
# ARI: 0.650
# Accuracy: 0.840
#
#
# NMI: 0.812
# ARI: 0.774
# Accuracy: 0.912
#
#
# NMI: 0.745
# ARI: 0.650
# Accuracy: 0.840
#
#
# NMI: 0.745
# ARI: 0.650
# Accuracy: 0.840
#
#
# NMI: 0.745
# ARI: 0.650
# Accuracy: 0.840
#
#
# NMI: 0.745
# ARI: 0.650
# Accuracy: 0.840
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.397
# ARI: 0.219
# Accuracy: 0.484
#
#
# NMI: 0.591
# ARI: 0.490
# Accuracy: 0.806
#
#
# NMI: 0.397
# ARI: 0.219
# Accuracy: 0.484
#
#
# NMI: 0.397
# ARI: 0.219
# Accuracy: 0.484
#
#
# NMI: 0.397
# ARI: 0.219
# Accuracy: 0.484
#
#
# NMI: 0.397
# ARI: 0.219
# Accuracy: 0.484
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.836
# ARI: 0.815
# Accuracy: 0.928
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.780
# ARI: 0.726
# Accuracy: 0.876
#
#
# NMI: 0.754
# ARI: 0.676
# Accuracy: 0.842
#
#
# NMI: 0.780
# ARI: 0.726
# Accuracy: 0.876
#
#
# NMI: 0.780
# ARI: 0.726
# Accuracy: 0.876
#
#
# NMI: 0.780
# ARI: 0.726
# Accuracy: 0.876
#
#
# NMI: 0.780
# ARI: 0.726
# Accuracy: 0.876
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.798
# ARI: 0.746
# Accuracy: 0.902
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.725
# ARI: 0.602
# Accuracy: 0.824
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.730
# ARI: 0.620
# Accuracy: 0.816
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.727
# ARI: 0.627
# Accuracy: 0.834
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.786
# ARI: 0.729
# Accuracy: 0.890
#
#
# NMI: 0.768
# ARI: 0.697
# Accuracy: 0.872
#
#
# NMI: 0.786
# ARI: 0.729
# Accuracy: 0.890
#
#
# NMI: 0.786
# ARI: 0.729
# Accuracy: 0.890
#
#
# NMI: 0.786
# ARI: 0.729
# Accuracy: 0.890
#
#
# NMI: 0.786
# ARI: 0.729
# Accuracy: 0.890
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.803
# ARI: 0.758
# Accuracy: 0.906
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.701
# ARI: 0.560
# Accuracy: 0.760
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.819
# ARI: 0.782
# Accuracy: 0.918
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.780
# ARI: 0.720
# Accuracy: 0.878
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.780
# ARI: 0.720
# Accuracy: 0.878
#
#
# NMI: 0.780
# ARI: 0.720
# Accuracy: 0.878
#
#
# NMI: 0.780
# ARI: 0.720
# Accuracy: 0.878
#
#
# NMI: 0.780
# ARI: 0.720
# Accuracy: 0.878
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.829
# ARI: 0.801
# Accuracy: 0.924
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.828
# ARI: 0.800
# Accuracy: 0.924
#
#
# NMI: 0.779
# ARI: 0.716
# Accuracy: 0.882
#
#
# NMI: 0.828
# ARI: 0.800
# Accuracy: 0.924
#
#
# NMI: 0.828
# ARI: 0.800
# Accuracy: 0.924
#
#
# NMI: 0.828
# ARI: 0.800
# Accuracy: 0.924
#
#
# NMI: 0.828
# ARI: 0.800
# Accuracy: 0.924
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.780
# ARI: 0.715
# Accuracy: 0.888
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.759
# ARI: 0.676
# Accuracy: 0.862
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.728
# ARI: 0.607
# Accuracy: 0.822
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.728
# ARI: 0.607
# Accuracy: 0.822
#
#
# NMI: 0.728
# ARI: 0.607
# Accuracy: 0.822
#
#
# NMI: 0.728
# ARI: 0.607
# Accuracy: 0.822
#
#
# NMI: 0.728
# ARI: 0.607
# Accuracy: 0.822
#
#
# NMI: 0.531
# ARI: 0.415
# Accuracy: 0.694
#
#
# NMI: 0.796
# ARI: 0.747
# Accuracy: 0.898
#
#
# NMI: 0.544
# ARI: 0.418
# Accuracy: 0.776
#
#
# NMI: 0.544
# ARI: 0.418
# Accuracy: 0.776
#
#
# NMI: 0.544
# ARI: 0.418
# Accuracy: 0.776
#
#
# NMI: 0.544
# ARI: 0.418
# Accuracy: 0.776
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.510
# ARI: 0.374
# Accuracy: 0.638
#
#
# NMI: 0.539
# ARI: 0.427
# Accuracy: 0.708
#
#
# NMI: 0.510
# ARI: 0.374
# Accuracy: 0.638
#
#
# NMI: 0.510
# ARI: 0.374
# Accuracy: 0.638
#
#
# NMI: 0.510
# ARI: 0.374
# Accuracy: 0.638
#
#
# NMI: 0.510
# ARI: 0.374
# Accuracy: 0.638
#
#
# NMI: 0.495
# ARI: 0.360
# Accuracy: 0.570
#
#
# NMI: 0.733
# ARI: 0.646
# Accuracy: 0.832
#
#
# NMI: 0.496
# ARI: 0.360
# Accuracy: 0.572
#
#
# NMI: 0.496
# ARI: 0.360
# Accuracy: 0.572
#
#
# NMI: 0.496
# ARI: 0.360
# Accuracy: 0.572
#
#
# NMI: 0.496
# ARI: 0.360
# Accuracy: 0.572
#
#
# NMI: 0.790
# ARI: 0.735
# Accuracy: 0.892
#
#
# NMI: 0.638
# ARI: 0.445
# Accuracy: 0.546
#
#
# NMI: 0.790
# ARI: 0.735
# Accuracy: 0.892
#
#
# NMI: 0.790
# ARI: 0.735
# Accuracy: 0.892
#
#
# NMI: 0.790
# ARI: 0.735
# Accuracy: 0.892
#
#
# NMI: 0.790
# ARI: 0.735
# Accuracy: 0.892
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.504
# ARI: 0.397
# Accuracy: 0.574
#
#
# NMI: 0.551
# ARI: 0.463
# Accuracy: 0.712
#
#
# NMI: 0.525
# ARI: 0.401
# Accuracy: 0.670
#
#
# NMI: 0.525
# ARI: 0.401
# Accuracy: 0.670
#
#
# NMI: 0.525
# ARI: 0.401
# Accuracy: 0.670
#
#
# NMI: 0.525
# ARI: 0.401
# Accuracy: 0.670
#
#
# NMI: 0.738
# ARI: 0.624
# Accuracy: 0.842
#
#
# NMI: 0.743
# ARI: 0.634
# Accuracy: 0.848
#
#
# NMI: 0.738
# ARI: 0.624
# Accuracy: 0.842
#
#
# NMI: 0.738
# ARI: 0.624
# Accuracy: 0.842
#
#
# NMI: 0.738
# ARI: 0.624
# Accuracy: 0.842
#
#
# NMI: 0.738
# ARI: 0.624
# Accuracy: 0.842
#
#
# NMI: 0.810
# ARI: 0.769
# Accuracy: 0.910
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.810
# ARI: 0.769
# Accuracy: 0.910
#
#
# NMI: 0.810
# ARI: 0.769
# Accuracy: 0.910
#
#
# NMI: 0.810
# ARI: 0.769
# Accuracy: 0.910
#
#
# NMI: 0.810
# ARI: 0.769
# Accuracy: 0.910
#
#
# NMI: 0.815
# ARI: 0.777
# Accuracy: 0.914
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.795
# ARI: 0.753
# Accuracy: 0.892
#
#
# NMI: 0.777
# ARI: 0.719
# Accuracy: 0.872
#
#
# NMI: 0.795
# ARI: 0.753
# Accuracy: 0.892
#
#
# NMI: 0.795
# ARI: 0.753
# Accuracy: 0.892
#
#
# NMI: 0.795
# ARI: 0.753
# Accuracy: 0.892
#
#
# NMI: 0.795
# ARI: 0.753
# Accuracy: 0.892
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.804
# ARI: 0.755
# Accuracy: 0.906
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.713
# ARI: 0.586
# Accuracy: 0.802
#
#
# NMI: 0.748
# ARI: 0.646
# Accuracy: 0.854
#
#
# NMI: 0.713
# ARI: 0.586
# Accuracy: 0.802
#
#
# NMI: 0.713
# ARI: 0.586
# Accuracy: 0.802
#
#
# NMI: 0.713
# ARI: 0.586
# Accuracy: 0.802
#
#
# NMI: 0.713
# ARI: 0.586
# Accuracy: 0.802
#
#
# NMI: 0.548
# ARI: 0.445
# Accuracy: 0.720
#
#
# NMI: 0.574
# ARI: 0.473
# Accuracy: 0.740
#
#
# NMI: 0.501
# ARI: 0.348
# Accuracy: 0.728
#
#
# NMI: 0.501
# ARI: 0.348
# Accuracy: 0.728
#
#
# NMI: 0.501
# ARI: 0.348
# Accuracy: 0.728
#
#
# NMI: 0.501
# ARI: 0.348
# Accuracy: 0.728
#
#
# NMI: 0.797
# ARI: 0.762
# Accuracy: 0.906
#
#
# NMI: 0.552
# ARI: 0.449
# Accuracy: 0.722
#
#
# NMI: 0.797
# ARI: 0.762
# Accuracy: 0.906
#
#
# NMI: 0.797
# ARI: 0.762
# Accuracy: 0.906
#
#
# NMI: 0.797
# ARI: 0.762
# Accuracy: 0.906
#
#
# NMI: 0.797
# ARI: 0.762
# Accuracy: 0.906
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.574
# ARI: 0.480
# Accuracy: 0.752
#
#
# NMI: 0.776
# ARI: 0.723
# Accuracy: 0.888
#
#
# NMI: 0.644
# ARI: 0.590
# Accuracy: 0.826
#
#
# NMI: 0.644
# ARI: 0.590
# Accuracy: 0.826
#
#
# NMI: 0.644
# ARI: 0.590
# Accuracy: 0.826
#
#
# NMI: 0.644
# ARI: 0.590
# Accuracy: 0.826
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.719
# ARI: 0.587
# Accuracy: 0.808
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.544
# ARI: 0.445
# Accuracy: 0.706
#
#
# NMI: 0.544
# ARI: 0.445
# Accuracy: 0.706
#
#
# NMI: 0.544
# ARI: 0.445
# Accuracy: 0.706
#
#
# NMI: 0.544
# ARI: 0.445
# Accuracy: 0.706
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.793
# ARI: 0.739
# Accuracy: 0.894
#
#
# NMI: 0.714
# ARI: 0.587
# Accuracy: 0.778
#
#
# NMI: 0.714
# ARI: 0.587
# Accuracy: 0.778
#
#
# NMI: 0.714
# ARI: 0.587
# Accuracy: 0.778
#
#
# NMI: 0.714
# ARI: 0.587
# Accuracy: 0.778
#
#
# NMI: 0.754
# ARI: 0.657
# Accuracy: 0.860
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.817
# ARI: 0.775
# Accuracy: 0.918
#
#
# NMI: 0.817
# ARI: 0.775
# Accuracy: 0.918
#
#
# NMI: 0.817
# ARI: 0.775
# Accuracy: 0.918
#
#
# NMI: 0.817
# ARI: 0.775
# Accuracy: 0.918
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.707
# ARI: 0.574
# Accuracy: 0.752
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.503
# ARI: 0.357
# Accuracy: 0.650
#
#
# NMI: 0.546
# ARI: 0.461
# Accuracy: 0.674
#
#
# NMI: 0.503
# ARI: 0.357
# Accuracy: 0.650
#
#
# NMI: 0.503
# ARI: 0.357
# Accuracy: 0.650
#
#
# NMI: 0.503
# ARI: 0.357
# Accuracy: 0.650
#
#
# NMI: 0.503
# ARI: 0.357
# Accuracy: 0.650
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.834
# ARI: 0.811
# Accuracy: 0.928
#
#
# NMI: 0.797
# ARI: 0.746
# Accuracy: 0.898
#
#
# NMI: 0.742
# ARI: 0.642
# Accuracy: 0.834
#
#
# NMI: 0.742
# ARI: 0.642
# Accuracy: 0.834
#
#
# NMI: 0.742
# ARI: 0.642
# Accuracy: 0.834
#
#
# NMI: 0.742
# ARI: 0.642
# Accuracy: 0.834
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.577
# ARI: 0.503
# Accuracy: 0.764
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.577
# ARI: 0.503
# Accuracy: 0.764
#
#
# NMI: 0.577
# ARI: 0.503
# Accuracy: 0.764
#
#
# NMI: 0.577
# ARI: 0.503
# Accuracy: 0.764
#
#
# NMI: 0.577
# ARI: 0.503
# Accuracy: 0.764
#
#
# NMI: 0.554
# ARI: 0.418
# Accuracy: 0.758
#
#
# NMI: 0.372
# ARI: 0.158
# Accuracy: 0.618
#
#
# NMI: 0.556
# ARI: 0.420
# Accuracy: 0.760
#
#
# NMI: 0.556
# ARI: 0.420
# Accuracy: 0.760
#
#
# NMI: 0.556
# ARI: 0.420
# Accuracy: 0.760
#
#
# NMI: 0.556
# ARI: 0.420
# Accuracy: 0.760
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.714
# ARI: 0.587
# Accuracy: 0.786
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.714
# ARI: 0.587
# Accuracy: 0.786
#
#
# NMI: 0.714
# ARI: 0.587
# Accuracy: 0.786
#
#
# NMI: 0.714
# ARI: 0.587
# Accuracy: 0.786
#
#
# NMI: 0.714
# ARI: 0.587
# Accuracy: 0.786
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.551
# ARI: 0.430
# Accuracy: 0.512
#
#
# NMI: 0.600
# ARI: 0.525
# Accuracy: 0.772
#
#
# NMI: 0.604
# ARI: 0.525
# Accuracy: 0.780
#
#
# NMI: 0.604
# ARI: 0.525
# Accuracy: 0.780
#
#
# NMI: 0.604
# ARI: 0.525
# Accuracy: 0.780
#
#
# NMI: 0.604
# ARI: 0.525
# Accuracy: 0.780
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.729
# ARI: 0.619
# Accuracy: 0.812
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.589
# ARI: 0.498
# Accuracy: 0.778
#
#
# NMI: 0.825
# ARI: 0.803
# Accuracy: 0.930
#
#
# NMI: 0.591
# ARI: 0.501
# Accuracy: 0.780
#
#
# NMI: 0.591
# ARI: 0.501
# Accuracy: 0.780
#
#
# NMI: 0.591
# ARI: 0.501
# Accuracy: 0.780
#
#
# NMI: 0.591
# ARI: 0.501
# Accuracy: 0.780
#
#
# NMI: 0.762
# ARI: 0.677
# Accuracy: 0.868
#
#
# NMI: 0.762
# ARI: 0.677
# Accuracy: 0.868
#
#
# NMI: 0.762
# ARI: 0.677
# Accuracy: 0.868
#
#
# NMI: 0.762
# ARI: 0.677
# Accuracy: 0.868
#
#
# NMI: 0.762
# ARI: 0.677
# Accuracy: 0.868
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.661
# ARI: 0.459
# Accuracy: 0.520
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.768
# ARI: 0.694
# Accuracy: 0.874
#
#
# NMI: 0.753
# ARI: 0.656
# Accuracy: 0.856
#
#
# NMI: 0.768
# ARI: 0.694
# Accuracy: 0.874
#
#
# NMI: 0.768
# ARI: 0.694
# Accuracy: 0.874
#
#
# NMI: 0.768
# ARI: 0.694
# Accuracy: 0.874
#
#
# NMI: 0.768
# ARI: 0.694
# Accuracy: 0.874
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.745
# ARI: 0.650
# Accuracy: 0.840
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.615
# ARI: 0.536
# Accuracy: 0.832
#
#
# NMI: 0.535
# ARI: 0.405
# Accuracy: 0.692
#
#
# NMI: 0.599
# ARI: 0.510
# Accuracy: 0.786
#
#
# NMI: 0.599
# ARI: 0.510
# Accuracy: 0.786
#
#
# NMI: 0.599
# ARI: 0.510
# Accuracy: 0.786
#
#
# NMI: 0.599
# ARI: 0.510
# Accuracy: 0.786
#
#
# NMI: 0.859
# ARI: 0.849
# Accuracy: 0.944
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.475
# ARI: 0.307
# Accuracy: 0.440
#
#
# NMI: 0.475
# ARI: 0.307
# Accuracy: 0.440
#
#
# NMI: 0.475
# ARI: 0.307
# Accuracy: 0.440
#
#
# NMI: 0.475
# ARI: 0.307
# Accuracy: 0.440
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.801
# ARI: 0.759
# Accuracy: 0.900
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.336
# ARI: 0.136
# Accuracy: 0.490
#
#
# NMI: 0.617
# ARI: 0.560
# Accuracy: 0.794
#
#
# NMI: 0.333
# ARI: 0.132
# Accuracy: 0.488
#
#
# NMI: 0.333
# ARI: 0.132
# Accuracy: 0.488
#
#
# NMI: 0.333
# ARI: 0.132
# Accuracy: 0.488
#
#
# NMI: 0.333
# ARI: 0.132
# Accuracy: 0.488
#
#
# NMI: 0.447
# ARI: 0.266
# Accuracy: 0.682
#
#
# NMI: 0.785
# ARI: 0.734
# Accuracy: 0.882
#
#
# NMI: 0.535
# ARI: 0.416
# Accuracy: 0.504
#
#
# NMI: 0.535
# ARI: 0.416
# Accuracy: 0.504
#
#
# NMI: 0.535
# ARI: 0.416
# Accuracy: 0.504
#
#
# NMI: 0.535
# ARI: 0.416
# Accuracy: 0.504
#
#
# NMI: 0.767
# ARI: 0.704
# Accuracy: 0.882
#
#
# NMI: 0.531
# ARI: 0.452
# Accuracy: 0.700
#
#
# NMI: 0.762
# ARI: 0.697
# Accuracy: 0.878
#
#
# NMI: 0.762
# ARI: 0.697
# Accuracy: 0.878
#
#
# NMI: 0.762
# ARI: 0.697
# Accuracy: 0.878
#
#
# NMI: 0.762
# ARI: 0.697
# Accuracy: 0.878
#
#
# NMI: 0.782
# ARI: 0.713
# Accuracy: 0.890
#
#
# NMI: 0.705
# ARI: 0.566
# Accuracy: 0.790
#
#
# NMI: 0.782
# ARI: 0.713
# Accuracy: 0.890
#
#
# NMI: 0.782
# ARI: 0.713
# Accuracy: 0.890
#
#
# NMI: 0.782
# ARI: 0.713
# Accuracy: 0.890
#
#
# NMI: 0.782
# ARI: 0.713
# Accuracy: 0.890
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.473
# ARI: 0.305
# Accuracy: 0.718
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.714
# ARI: 0.589
# Accuracy: 0.782
#
#
# NMI: 0.786
# ARI: 0.726
# Accuracy: 0.888
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.978
# ARI: 0.988
# Accuracy: 0.996
#
#
# NMI: 0.859
# ARI: 0.857
# Accuracy: 0.950
#
#
# NMI: 0.978
# ARI: 0.988
# Accuracy: 0.996
#
#
# NMI: 0.978
# ARI: 0.988
# Accuracy: 0.996
#
#
# NMI: 0.978
# ARI: 0.988
# Accuracy: 0.996
#
#
# NMI: 0.978
# ARI: 0.988
# Accuracy: 0.996
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.837
# ARI: 0.814
# Accuracy: 0.930
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.542
# ARI: 0.422
# Accuracy: 0.700
#
#
# NMI: 0.858
# ARI: 0.855
# Accuracy: 0.942
#
#
# NMI: 0.540
# ARI: 0.419
# Accuracy: 0.696
#
#
# NMI: 0.540
# ARI: 0.419
# Accuracy: 0.696
#
#
# NMI: 0.540
# ARI: 0.419
# Accuracy: 0.696
#
#
# NMI: 0.540
# ARI: 0.419
# Accuracy: 0.696
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.739
# ARI: 0.641
# Accuracy: 0.826
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.851
# ARI: 0.834
# Accuracy: 0.940
#
#
# NMI: 0.716
# ARI: 0.586
# Accuracy: 0.796
#
#
# NMI: 0.851
# ARI: 0.834
# Accuracy: 0.940
#
#
# NMI: 0.851
# ARI: 0.834
# Accuracy: 0.940
#
#
# NMI: 0.851
# ARI: 0.834
# Accuracy: 0.940
#
#
# NMI: 0.851
# ARI: 0.834
# Accuracy: 0.940
#
#
# NMI: 0.838
# ARI: 0.816
# Accuracy: 0.932
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.558
# ARI: 0.451
# Accuracy: 0.700
#
#
# NMI: 0.625
# ARI: 0.543
# Accuracy: 0.828
#
#
# NMI: 0.576
# ARI: 0.487
# Accuracy: 0.746
#
#
# NMI: 0.576
# ARI: 0.487
# Accuracy: 0.746
#
#
# NMI: 0.576
# ARI: 0.487
# Accuracy: 0.746
#
#
# NMI: 0.576
# ARI: 0.487
# Accuracy: 0.746
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.342
# ARI: 0.164
# Accuracy: 0.474
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.737
# ARI: 0.640
# Accuracy: 0.824
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.772
# ARI: 0.702
# Accuracy: 0.876
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.799
# ARI: 0.747
# Accuracy: 0.902
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.565
# ARI: 0.461
# Accuracy: 0.728
#
#
# NMI: 0.754
# ARI: 0.663
# Accuracy: 0.856
#
#
# NMI: 0.598
# ARI: 0.505
# Accuracy: 0.816
#
#
# NMI: 0.598
# ARI: 0.505
# Accuracy: 0.816
#
#
# NMI: 0.598
# ARI: 0.505
# Accuracy: 0.816
#
#
# NMI: 0.598
# ARI: 0.505
# Accuracy: 0.816
#
#
# NMI: 0.504
# ARI: 0.374
# Accuracy: 0.654
#
#
# NMI: 0.736
# ARI: 0.629
# Accuracy: 0.828
#
#
# NMI: 0.504
# ARI: 0.374
# Accuracy: 0.654
#
#
# NMI: 0.504
# ARI: 0.374
# Accuracy: 0.654
#
#
# NMI: 0.504
# ARI: 0.374
# Accuracy: 0.654
#
#
# NMI: 0.504
# ARI: 0.374
# Accuracy: 0.654
#
#
# NMI: 0.725
# ARI: 0.602
# Accuracy: 0.812
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.722
# ARI: 0.611
# Accuracy: 0.782
#
#
# NMI: 0.722
# ARI: 0.611
# Accuracy: 0.782
#
#
# NMI: 0.722
# ARI: 0.611
# Accuracy: 0.782
#
#
# NMI: 0.722
# ARI: 0.611
# Accuracy: 0.782
#
#
# NMI: 0.714
# ARI: 0.592
# Accuracy: 0.766
#
#
# NMI: 0.816
# ARI: 0.783
# Accuracy: 0.914
#
#
# NMI: 0.714
# ARI: 0.592
# Accuracy: 0.766
#
#
# NMI: 0.714
# ARI: 0.592
# Accuracy: 0.766
#
#
# NMI: 0.714
# ARI: 0.592
# Accuracy: 0.766
#
#
# NMI: 0.714
# ARI: 0.592
# Accuracy: 0.766
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.546
# ARI: 0.425
# Accuracy: 0.478
#
#
# NMI: 0.618
# ARI: 0.554
# Accuracy: 0.802
#
#
# NMI: 0.547
# ARI: 0.427
# Accuracy: 0.476
#
#
# NMI: 0.547
# ARI: 0.427
# Accuracy: 0.476
#
#
# NMI: 0.547
# ARI: 0.427
# Accuracy: 0.476
#
#
# NMI: 0.547
# ARI: 0.427
# Accuracy: 0.476
#
#
# NMI: 0.583
# ARI: 0.495
# Accuracy: 0.770
#
#
# NMI: 0.540
# ARI: 0.411
# Accuracy: 0.762
#
#
# NMI: 0.529
# ARI: 0.418
# Accuracy: 0.686
#
#
# NMI: 0.529
# ARI: 0.418
# Accuracy: 0.686
#
#
# NMI: 0.529
# ARI: 0.418
# Accuracy: 0.686
#
#
# NMI: 0.529
# ARI: 0.418
# Accuracy: 0.686
#
#
# NMI: 0.841
# ARI: 0.821
# Accuracy: 0.932
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 0.734
# ARI: 0.618
# Accuracy: 0.836
#
#
# NMI: 0.709
# ARI: 0.568
# Accuracy: 0.796
#
#
# NMI: 0.764
# ARI: 0.677
# Accuracy: 0.872
#
#
# NMI: 0.764
# ARI: 0.677
# Accuracy: 0.872
#
#
# NMI: 0.764
# ARI: 0.677
# Accuracy: 0.872
#
#
# NMI: 0.764
# ARI: 0.677
# Accuracy: 0.872
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.744
# ARI: 0.646
# Accuracy: 0.848
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 0.989
# ARI: 0.994
# Accuracy: 0.998
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000
#
#
# NMI: 1.000
# ARI: 1.000
# Accuracy: 1.000

# %%
# for j in ['admin', 'norm', 'unif']:

#     # Create a DataFrame for grouping
#     df_acc = pd.DataFrame({"Accuracy": accuracy_all[j], "Gamma": gammapars_all[j]})

#     plt.figure(figsize=(6, 5))

#     # Use seaborn boxplot with greyscale palette for consistency
#     sns.boxplot(
#         data=df_acc,
#         x="Gamma",
#         y="Accuracy",
#         palette="Greys"
#     )



#     # Styling
#     plt.title(f"{numb[j]}", fontsize=TITLE_SIZE)
#     plt.xlabel(r"$\gamma$", fontsize=LABEL_SIZE)
#     plt.ylabel("Accuracy", fontsize=LABEL_SIZE)
#     plt.grid(axis='y', linestyle='--', alpha=0.5)

#     plt.xticks(fontsize=TICK_SIZE)
#     plt.yticks(fontsize=TICK_SIZE)

#     plt.tight_layout()

#     # Save the figure (PDF for LaTeX)
#     plt.savefig(f"Plots/fig_Accuracy_{j}.pdf", bbox_inches="tight")
#     plt.close()

# %%
# for j in ['admin', 'norm', 'unif']:

#     # Create a DataFrame for grouping
#     df_acc = pd.DataFrame({"ARI": ari_all[j], "Gamma": gammapars_all[j]})

#     plt.figure(figsize=(6, 5))

#     # Use seaborn boxplot with greyscale palette for consistency
#     sns.boxplot(
#         data=df_acc,
#         x="Gamma",
#         y="ARI",
#         palette="Greys"
#     )

#     # Styling
#     plt.title(f"{numb[j]}", fontsize=TITLE_SIZE)
#     plt.xlabel(r"$\gamma$", fontsize=LABEL_SIZE)
#     plt.ylabel("ARI", fontsize=LABEL_SIZE)
#     plt.grid(axis='y', linestyle='--', alpha=0.5)

#     plt.xticks(fontsize=TICK_SIZE)
#     plt.yticks(fontsize=TICK_SIZE)

#     plt.tight_layout()

#     # Save the figure (PDF for LaTeX)
#     plt.savefig(f"Plots/fig_ARI_{j}.pdf", bbox_inches="tight")
#     plt.close()

# %%
# for j in ['admin', 'norm', 'unif']:

#     # Create a DataFrame for grouping
#     df_acc = pd.DataFrame({"NMI": nmi_all[j], "Gamma": gammapars_all[j]})

#     plt.figure(figsize=(6, 5))

#     # Use seaborn boxplot with greyscale palette for consistency
#     sns.boxplot(
#         data=df_acc,
#         x="Gamma",
#         y="NMI",
#         palette="Greys"
#     )


#     # Styling
#     plt.title(f"{numb[j]}", fontsize=TITLE_SIZE)
#     plt.xlabel(r"$\gamma$", fontsize=LABEL_SIZE)
#     plt.ylabel("NMI", fontsize=LABEL_SIZE)
#     plt.grid(axis='y', linestyle='--', alpha=0.5)

#     plt.xticks(fontsize=TICK_SIZE)
#     plt.yticks(fontsize=TICK_SIZE)

#     plt.tight_layout()

#     # Save the figure (PDF for LaTeX)
#     plt.savefig(f"Plots/fig_NMI_{j}.pdf", bbox_inches="tight")
#     plt.close()

# %%
import matplotlib.patches as mpatches
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

titles_acc = {
    'admin': "(i) Accuracy – Administrative cens.",
    'norm':  "(ii) Accuracy – Normal cens.",
}

titles_ari = {
    'admin': "(iii) ARI – Administrative cens.",
    'norm':  "(iv) ARI – Normal cens.",
}

# -------------------------------
# Create 2×2 figure
# -------------------------------
fig, axes = plt.subplots(1, 4, figsize=(18, 4), sharey=False)

# store gamma values once
gammas_used = None

# --------------------------------
# First row: ACCURACY
# --------------------------------
for col, j in enumerate(['admin', 'norm']):

    df_acc = pd.DataFrame({
        "Value": accuracy_all[j],
        "Gamma": gammapars_all[j]
    })

    if gammas_used is None:
        gammas_used = np.sort(df_acc["Gamma"].unique())

    sns.boxplot(
        data=df_acc,
        x="Gamma",
        y="Value",
        palette="Greys",
        ax=axes[col]
    )

    ax = axes[col]
    ax.set_title(titles_acc[j], fontsize=TITLE_SIZE-5)
    ax.set_xlabel("")
    ax.set_ylabel("")
    ax.set_xticks([])
    ax.set_xticklabels([])

# --------------------------------
# Second row: ARI
# --------------------------------
for col, j in enumerate(['admin', 'norm']):

    df_ari = pd.DataFrame({
        "Value": ari_all[j],        # your ARI values here
        "Gamma": gammapars_all[j]
    })

    sns.boxplot(
        data=df_ari,
        x="Gamma",
        y="Value",
        palette="Greys",
        ax=axes[col+2]
    )

    ax = axes[col+2]
    ax.set_title(titles_ari[j], fontsize=TITLE_SIZE-5)
    ax.set_xlabel("")
    ax.set_ylabel("")
    ax.set_xticks([])
    ax.set_xticklabels([])

# --------------------------------
# Build the global gamma legend
# --------------------------------
colors = sns.color_palette("Greys", len(gammas_used))

labels = []
for g in gammas_used:
    if g == 0:
        labels.append("0")
    elif abs(g) < 0.01:
        e = int(np.floor(np.log10(abs(g))))
        labels.append(rf"$10^{{{e}}}$")
    else:
        labels.append(f"{g:g}")

handles = [
    mpatches.Patch(facecolor=colors[k], label=labels[k], 
                   edgecolor="black",  
                   linewidth=0.5)
    for k in range(len(gammas_used))
]

fig.legend(
    handles,
    labels,
    title=r"$\gamma$",
    loc="lower center",
    ncol=len(labels),
    fontsize=TICK_SIZE,
    title_fontsize=TICK_SIZE
)

# Add spacing and global title
fig.subplots_adjust(top=0.85, bottom=0.28)

#fig.suptitle("Accuracy and ARI – Censoring Comparison", fontsize=TITLE_SIZE)

plt.savefig("Plots/Fig_Accuracy_ARI_All.pdf", bbox_inches="tight")
plt.close()
